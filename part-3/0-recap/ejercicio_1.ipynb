# %% [markdown]
# ## 00-Ejercicio-merges

# %%
df1 = pd.DataFrame({'A': np.random.randint(1, 100, 10),
                    'B': np.random.randint(1, 100, 10),
                    'key': list(range(1, 6)) * 2})

df2 = pd.DataFrame({'C': np.random.randint(1, 100, 7),
                    'D': np.random.randint(1, 100, 7),
                    'key': list(range(2, 9))})

print("Sample data generated.")
# Out:
# Sample data generated.

# %%
print("Inner Merge:")
#generar inner merge. ¿Que significa?
print(inner_merged)
# Out:
# Inner Merge:
#     A   B  key   C   D
# 0  99  73    2  21  27
# 1  95  15    2  21  27
# 2  31  55    3  99  48
# 3  64  78    3  99  48
# 4  93  60    4  45  60
# 5  23  83    4  45  60
# 6  37  88    5  74  96
# 7  71  48    5  74  96

# %%
print("Outer Merge:")
#generar outer merge
print(outer_merged)
# Out:
# Outer Merge:
#         A      B  key      C      D
# 0  62.000 37.000    1    NaN    NaN
# 1  92.000 39.000    1    NaN    NaN
# 2  99.000 73.000    2 21.000 27.000
# 3  95.000 15.000    2 21.000 27.000
# 4  31.000 55.000    3 99.000 48.000
# 5  64.000 78.000    3 99.000 48.000
# 6  93.000 60.000    4 45.000 60.000
# 7  23.000 83.000    4 45.000 60.000
# 8  37.000 88.000    5 74.000 96.000
# 9  71.000 48.000    5 74.000 96.000
# 10    NaN    NaN    6 47.000 69.000
# 11    NaN    NaN    7 73.000 34.000
# 12    NaN    NaN    8 79.000 99.000

# %%
print("Left Merge:")
#generar left merge
print(left_merged)
# Out:
# Left Merge:
#     A   B  key      C      D
# 0  62  37    1    NaN    NaN
# 1  99  73    2 21.000 27.000
# 2  31  55    3 99.000 48.000
# 3  93  60    4 45.000 60.000
# 4  37  88    5 74.000 96.000
# 5  92  39    1    NaN    NaN
# 6  95  15    2 21.000 27.000
# 7  64  78    3 99.000 48.000
# 8  23  83    4 45.000 60.000
# 9  71  48    5 74.000 96.000

# %%
print("Right Merge:")
#generar right merge
print(right_merged)
# Out:
# Right Merge:
#         A      B  key   C   D
# 0  99.000 73.000    2  21  27
# 1  95.000 15.000    2  21  27
# 2  31.000 55.000    3  99  48
# 3  64.000 78.000    3  99  48
# 4  93.000 60.000    4  45  60
# 5  23.000 83.000    4  45  60
# 6  37.000 88.000    5  74  96
# 7  71.000 48.000    5  74  96
# 8     NaN    NaN    6  47  69
# 9     NaN    NaN    7  73  34
# 10    NaN    NaN    8  79  99

# %%
print("Correlation Matrix:")
#generar matriz de correlacion con el dataset de inner merge
print(corr_matrix)
# Out:
# Correlation Matrix:
#          A      B    key      C      D
# A    1.000 -0.502 -0.462 -0.587 -0.435
# B   -0.502  1.000  0.387  0.313  0.342
# key -0.462  0.387  1.000  0.399  0.978
# C   -0.587  0.313  0.399  1.000  0.448
# D   -0.435  0.342  0.978  0.448  1.000

# %%
print("Heatmap:")
#plotear un heatmap con seaborn
plt.show()
# Out:
# Heatmap:
